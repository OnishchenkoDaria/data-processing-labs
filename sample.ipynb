# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("./data/tools.csv")
df
# Out:
#                     Name Variation Body Title  DIY Customize  Kit Cost  \
# 0                    axe       NaN        NaN  Yes        No       NaN
# 1            bamboo wand       NaN        NaN  Yes        No       NaN
# 2               bug wand       NaN        NaN   No        No       NaN
# 3         Bunny Day wand       NaN        NaN  Yes        No       NaN
# 4    cherry-blossom wand       NaN        NaN  Yes        No       NaN
# ..                   ...       ...        ...  ...       ...       ...
# 195         watering can     White      Color  Yes       Yes       1.0
# 196         watering can     Black      Color  Yes       Yes       1.0
# 197         wedding wand       NaN        NaN  Yes        No       NaN
# 198      windflower wand       NaN        NaN  Yes        No       NaN
# 199             worn axe       NaN        NaN   No        No       NaN
#
#           Uses  Stack Size   Buy   Sell  ... Size  Set Miles Price  \
# ...

# %%
df.head(5)
# Out:
#                   Name Variation Body Title  DIY Customize  Kit Cost  \
# 0                  axe       NaN        NaN  Yes        No       NaN
# 1          bamboo wand       NaN        NaN  Yes        No       NaN
# 2             bug wand       NaN        NaN   No        No       NaN
# 3       Bunny Day wand       NaN        NaN  Yes        No       NaN
# 4  cherry-blossom wand       NaN        NaN  Yes        No       NaN
#
#         Uses  Stack Size   Buy   Sell  ... Size  Set Miles Price  \
# 0        100           1  2500    625  ...  1x1  NaN         NaN
# 1  Unlimited           1   NFS   3900  ...  1x1  NaN         NaN
# 2  Unlimited           1   NFS   1500  ...  1x1  NaN         NaN
# 3  Unlimited           1   NFS  11100  ...  1x1  NaN         NaN
# 4  Unlimited           1   NFS   2700  ...  1x1  NaN         NaN
#
#                     Source  Source Notes Version                Filename  \
# 0  Nook's Cranny; Crafting           NaN   1.0.0                 ToolAxe
# ...

# %%
df = df[['Name', 'Uses', 'Sell', 'Variation', 'Set','Source', 'Filename', 'Internal ID']]
df
# Out:
#                     Name       Uses   Sell Variation  Set  \
# 0                    axe        100    625       NaN  NaN
# 1            bamboo wand  Unlimited   3900       NaN  NaN
# 2               bug wand  Unlimited   1500       NaN  NaN
# 3         Bunny Day wand  Unlimited  11100       NaN  NaN
# 4    cherry-blossom wand  Unlimited   2700       NaN  NaN
# ..                   ...        ...    ...       ...  ...
# 195         watering can         60    600     White  NaN
# 196         watering can         60    600     Black  NaN
# 197         wedding wand  Unlimited   3500       NaN  NaN
# 198      windflower wand  Unlimited   1580       NaN  NaN
# 199             worn axe          3     10       NaN  NaN
#
#                       Source                 Filename  Internal ID
# 0    Nook's Cranny; Crafting                  ToolAxe         2100
# 1                   Crafting          ToolStickBamboo         7590
# ...

# %%
df.isna().sum()
# Out:
# Name             0
# Uses             0
# Sell             0
# Variation       44
# Set            120
# Source           0
# Filename         0
# Internal ID      0
# dtype: int64
